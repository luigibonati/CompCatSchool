# %%
import chemiscope

# %%
chemiscope.show_input('threshold0.1/deal_selected_chemiscope.json.gz')
# Out:
# <ChemiscopeWidget(meta={'name': 'DEAL selection'}, settings={'structure': [{'atoms': False, 'bonds': False, 's…
